# %% [markdown]
# <a href="https://colab.research.google.com/github/SizzlingDonut/Python-DataScience/blob/main/Seaborn/Seaborn05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
crash_df = sns.load_dataset('car_crashes')
tips_df = sns.load_dataset('tips')

sns.barplot(x='sex', y='total_bill', data=tips_df)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>
