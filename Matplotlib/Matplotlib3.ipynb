# %% [markdown]
# <a href="https://colab.research.google.com/github/SizzlingDonut/Python-DataScience/blob/main/Matplotlib/Matplotlib3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array([2023, 2024, 2025, 2026])
y1 = np.array([15, 25, 30, 20])
y2 = np.array([17, 23, 38, 5])
y3 = np.array([13, 15, 20, 30])

plt.title("Class Size", fontsize = 25,
                        fontweight = "bold",
                        color = "#2d4cfc")

plt.xlabel("Year", fontsize = 20,
                   fontweight = "bold",
                   color = "purple")

plt.ylabel("Students", fontsize = 20,
                   fontweight = "bold",
                   color = "purple")

plt.tick_params(axis = "both",
                colors = "purple")

plt.plot(x, y1)
plt.plot(x, y2)
plt.plot(x, y3)

plt.xticks(x)

plt.show()
